# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
plt.style.use("seaborn")

import matplotlib as mpl

mpl.style.use("default")

# %%
dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

plt.plot_date(dates, y, linestyle = "solid")
plt.grid()

# get current figur gcf method pavercia (rotate) datas

plt.gcf().autofmt_xdate()
# nustatome datos formata ir tada get current axis funkcija iterpiame datos formata ant x asies
date_format = mpl_dates.DateFormatter("%b, %d %Y")

#get current axis
plt.gca().xaxis.set_major_formatter(date_format)

#data = pd.read_csv("C:/Users/Vartotojas/Desktop/kursai online/Matplotlib/data5.csv")
# price_date = data["Date"]
# price_close = data["Close"]

# plt.title["Bitcoin prices"]
# plt.xlabel["Date"]
# plt.ylabel["Closing Price"]

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

plt.grid()

data = pd.read_csv("C:/Users/Vartotojas/Desktop/kursai online/Matplotlib/data5.csv")

#konvertuojame string data i panda datetime metoda
data["Date"] = pd.to_datetime(data["Date"])
data.sort_values("Date", inplace =True)


price_date = data["Date"]
price_close = data["Close"]

plt.plot_date(price_date, price_close, linestyle = "solid")
plt.gcf().autofmt_xdate()

plt.title("Bitcoin prices")
plt.xlabel("Date")
plt.ylabel("Closing Price")


plt.tight_layout()
plt.show()
